# %% [markdown]
# Notebook for creating the song_metadata.json file containing more metadata for songs in spotify_songs.csv.
#
# Uses the spotify API to retrieve song metadata

# %%
import pandas as pd
import json
import csv
from dotenv import load_dotenv
import os
import time
import requests

# %%
load_dotenv() # Load env variables from .env file

# Get Spotify api credentials from environment variables
client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

# Get the access token
auth_url = 'https://accounts.spotify.com/api/token'
auth_data = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret
}
auth_response = requests.post(auth_url, data=auth_data)
access_token = auth_response.json()['access_token']

# Set up the API endpoint and headers
api_url = 'https://api.spotify.com/v1/tracks'
headers = {
    'Authorization': f'Bearer {access_token}'
}

# %%
csv_file = "../dataset/spotify_songs.csv"
df = pd.read_csv(csv_file)

# %% [markdown]
# ## Using the Spotify API
# Take the songs from csv file and calls the tracks api to get song metadata.
#
# Saved in song_metadata.json

# %%
# %time 
# Load existing song metadata from the JSON file if it exists
if os.path.exists('temp_data/song_metadata_2.json'):
    with open('temp_data/song_metadata_2.json', 'r') as file:
        song_metadata = json.load(file)
else:
    song_metadata = []

id_start = 0 # update this with the index of the song you want to start with
batch_size = 30
# Create batches of 10 track IDs
track_id_batches = [df['track_id'].tolist()[i:i+batch_size] for i in range(id_start, len(df), batch_size)]

# Iterate over each batch of track IDs
for i, batch in enumerate(track_id_batches):
    print(f"Processing batch {i+1}/{len(track_id_batches)}")
    
    # Create the API request parameters
    params = {
        'ids': ','.join(batch)
    }
    
    # Retry the API request until a successful response is received
    while True:
        # Make the API request
        response = requests.get(api_url, headers=headers, params=params)
        print(response)
        
        if response.status_code == 200:
            track_results = response.json()
            
            # Iterate over each track in the batch
            for track in track_results['tracks']:
                if track:
                    track_id = track['id']
                    track_url = track['external_urls']['spotify']
                    preview_url = track['preview_url']
                    image_url = track['album']['images'][0]['url'] if track['album']['images'] else ""
                    artists = [artist["name"] for artist in track["album"]["artists"]]
                    
                    # Find the corresponding index in the DataFrame
                    index = df.index[df['track_id'] == track_id].tolist()[0]
                    
                    # Create a dictionary with the song metadata
                    song_info = {
                        'id': index,
                        'name': df.loc[index, 'track_name'],
                        'track_id': track_id,
                        'artists': artists,
                        'image_url': image_url,
                        'track_url': track_url,
                        'preview_url': preview_url
                    }
                    
                    song_metadata.append(song_info)
            
            # Save the updated song metadata to the JSON file after processing each batch
            with open('temp_data/song_metadata_2.json', 'w') as file:
                json.dump(song_metadata, file, indent=4)
            
            # Break out of the retry loop since a successful response was received
            break
        
        else:
            print(f"API request failed with status code {response.status_code}")
            print("Retrying in 30 seconds...")
            time.sleep(30)  # Sleep for 5 seconds before retrying

print("Data retrieval completed")
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# Processing batch 1/1095
# <Response [200]>
# Processing batch 2/1095
# <Response [200]>
# Processing batch 3/1095
# <Response [200]>
# Processing batch 4/1095
# <Response [200]>
# Processing batch 5/1095
# <Response [200]>
# Processing batch 6/1095
# <Response [200]>
# Processing batch 7/1095
# <Response [200]>
# Processing batch 8/1095
# <Response [200]>
# Processing batch 9/1095
# <Response [200]>
# Processing batch 10/1095
# <Response [200]>
# Processing batch 11/1095
# <Response [200]>
# Processing batch 12/1095
# <Response [200]>
# Processing batch 13/1095
# <Response [200]>
# Processing batch 14/1095
# <Response [200]>
# Processing batch 15/1095
# <Response [200]>
# Processing batch 16/1095
# <Response [200]>
# Processing batch 17/1095
# <Response [200]>
# Processing batch 18/1095
# <Response [200]>
# Processing batch 19/1095
# <Response [200]>
# Processing batch 20/1095
# <Response [200]>
# Processing batch 21/1095
# <Response [200]>
# Processing batch 22/1095
# <Response [200]>
# Processing batch 23/1095
# <Response [200]>
# Processing batch 24/1095
# <Response [200]>
# Processing batch 25/1095
# <Response [200]>
# Processing batch 26/1095
# <Response [200]>
# Processing batch 27/1095
# <Response [200]>
# Processing batch 28/1095
# <Response [200]>
# Processing batch 29/1095
# <Response [200]>
# Processing batch 30/1095
# <Response [200]>
# Processing batch 31/1095
# <Response [200]>
# Processing batch 32/1095
# <Response [200]>
# Processing batch 33/1095
# <Response [200]>
# Processing batch 34/1095
# <Response [200]>
# Processing batch 35/1095
# <Response [200]>
# Processing batch 36/1095
# <Response [200]>
# Processing batch 37/1095
# <Response [200]>
# Processing batch 38/1095
# <Response [200]>
# Processing batch 39/1095
# <Response [200]>
# Processing batch 40/1095
# <Response [200]>
# Processing batch 41/1095
# <Response [200]>
# Processing batch 42/1095
# <Response [200]>
# Processing batch 43/1095
# <Response [200]>
# Processing batch 44/1095
# <Response [200]>
# Processing batch 45/1095
# <Response [200]>
# Processing batch 46/1095
# <Response [200]>
# Processing batch 47/1095
# <Response [200]>
# Processing batch 48/1095
# <Response [200]>
# Processing batch 49/1095
# <Response [200]>
# Processing batch 50/1095
# <Response [200]>
# Processing batch 51/1095
# <Response [200]>
# Processing batch 52/1095
# <Response [200]>
# Processing batch 53/1095
# <Response [200]>
# Processing batch 54/1095
# <Response [200]>
# Processing batch 55/1095
# <Response [200]>
# Processing batch 56/1095
# <Response [200]>
# Processing batch 57/1095
# <Response [200]>
# Processing batch 58/1095
# <Response [200]>
# Processing batch 59/1095
# <Response [200]>
# Processing batch 60/1095
# <Response [200]>
# Processing batch 61/1095
# <Response [200]>
# Processing batch 62/1095
# <Response [200]>
# Processing batch 63/1095
# <Response [200]>
# Processing batch 64/1095
# <Response [200]>
# Processing batch 65/1095
# <Response [200]>
# Processing batch 66/1095
# <Response [200]>
# Processing batch 67/1095
# <Response [200]>
# Processing batch 68/1095
# <Response [200]>
# Processing batch 69/1095
# <Response [200]>
# Processing batch 70/1095
# <Response [200]>
# Processing batch 71/1095
# <Response [200]>
# Processing batch 72/1095
# <Response [200]>
# Processing batch 73/1095
# <Response [200]>
# Processing batch 74/1095
# <Response [200]>
# Processing batch 75/1095
# <Response [200]>
# Processing batch 76/1095
# <Response [200]>
# Processing batch 77/1095
# <Response [200]>
# Processing batch 78/1095
# <Response [200]>
# Processing batch 79/1095
# <Response [200]>
# Processing batch 80/1095
# <Response [200]>
# Processing batch 81/1095
# <Response [200]>
# Processing batch 82/1095
# <Response [200]>
# Processing batch 83/1095
# <Response [200]>
# Processing batch 84/1095
# <Response [200]>
# Processing batch 85/1095
# <Response [200]>
# Processing batch 86/1095
# <Response [200]>
# Processing batch 87/1095
# <Response [200]>
# Processing batch 88/1095
# <Response [200]>
# Processing batch 89/1095
# <Response [200]>
# Processing batch 90/1095
# <Response [200]>
# Processing batch 91/1095
# <Response [200]>
# Processing batch 92/1095
# <Response [200]>
# Processing batch 93/1095
# <Response [200]>
# Processing batch 94/1095
# <Response [200]>
# Processing batch 95/1095
# <Response [200]>
# Processing batch 96/1095
# <Response [200]>
# Processing batch 97/1095
# <Response [200]>
# Processing batch 98/1095
# <Response [200]>
# Processing batch 99/1095
# <Response [200]>
# Processing batch 100/1095
# <Response [200]>
# Processing batch 101/1095
# <Response [200]>
# Processing batch 102/1095
# <Response [200]>
# Processing batch 103/1095
# <Response [200]>
# Processing batch 104/1095
# <Response [200]>
# Processing batch 105/1095
# <Response [200]>
# Processing batch 106/1095
# <Response [200]>
# Processing batch 107/1095
# <Response [200]>
# Processing batch 108/1095
# <Response [200]>
# Processing batch 109/1095
# <Response [200]>
# Processing batch 110/1095
# <Response [200]>
# Processing batch 111/1095
# <Response [200]>
# Processing batch 112/1095
# <Response [200]>
# Processing batch 113/1095
# <Response [200]>
# Processing batch 114/1095
# <Response [200]>
# Processing batch 115/1095
# <Response [200]>
# Processing batch 116/1095
# <Response [200]>
# Processing batch 117/1095
# <Response [200]>
# Processing batch 118/1095
# <Response [200]>
# Processing batch 119/1095
# <Response [200]>
# Processing batch 120/1095
# <Response [200]>
# Processing batch 121/1095
# <Response [200]>
# Processing batch 122/1095
# <Response [200]>
# Processing batch 123/1095
# <Response [200]>
# Processing batch 124/1095
# <Response [200]>
# Processing batch 125/1095
# <Response [200]>
# Processing batch 126/1095
# <Response [200]>
# Processing batch 127/1095
# <Response [200]>
# Processing batch 128/1095
# <Response [200]>
# Processing batch 129/1095
# <Response [200]>
# Processing batch 130/1095
# <Response [200]>
# Processing batch 131/1095
# <Response [200]>
# Processing batch 132/1095
# <Response [200]>
# Processing batch 133/1095
# <Response [200]>
# Processing batch 134/1095
# <Response [200]>
# Processing batch 135/1095
# <Response [200]>
# Processing batch 136/1095
# <Response [200]>
# Processing batch 137/1095
# <Response [200]>
# Processing batch 138/1095
# <Response [200]>
# Processing batch 139/1095
# <Response [200]>
# Processing batch 140/1095
# <Response [200]>
# Processing batch 141/1095
# <Response [200]>
# Processing batch 142/1095
# <Response [200]>
# Processing batch 143/1095
# <Response [200]>
# Processing batch 144/1095
# <Response [200]>
# Processing batch 145/1095
# <Response [200]>
# Processing batch 146/1095
# <Response [200]>
# Processing batch 147/1095
# <Response [200]>
# Processing batch 148/1095
# <Response [200]>
# Processing batch 149/1095
# <Response [200]>
# Processing batch 150/1095
# <Response [200]>
# Processing batch 151/1095
# <Response [200]>
# Processing batch 152/1095
# <Response [200]>
# Processing batch 153/1095
# <Response [200]>
# Processing batch 154/1095
# <Response [200]>
# Processing batch 155/1095
# <Response [200]>
# Processing batch 156/1095
# <Response [200]>
# Processing batch 157/1095
# <Response [200]>
# Processing batch 158/1095
# <Response [200]>
# Processing batch 159/1095
# <Response [200]>
# Processing batch 160/1095
# <Response [200]>
# Processing batch 161/1095
# <Response [200]>
# Processing batch 162/1095
# <Response [200]>
# Processing batch 163/1095
# <Response [200]>
# Processing batch 164/1095
# <Response [200]>
# Processing batch 165/1095
# <Response [200]>
# Processing batch 166/1095
# <Response [200]>
# Processing batch 167/1095
# <Response [200]>
# Processing batch 168/1095
# <Response [200]>
# Processing batch 169/1095
# <Response [200]>
# Processing batch 170/1095
# <Response [200]>
# Processing batch 171/1095
# <Response [200]>
# Processing batch 172/1095
# <Response [200]>
# Processing batch 173/1095
# <Response [200]>
# Processing batch 174/1095
# <Response [200]>
# Processing batch 175/1095
# <Response [200]>
# Processing batch 176/1095
# <Response [200]>
# Processing batch 177/1095
# <Response [200]>
# Processing batch 178/1095
# <Response [200]>
# Processing batch 179/1095
# <Response [200]>
# Processing batch 180/1095
# <Response [200]>
# Processing batch 181/1095
# <Response [200]>
# Processing batch 182/1095
# <Response [200]>
# Processing batch 183/1095
# <Response [200]>
# Processing batch 184/1095
# <Response [200]>
# Processing batch 185/1095
# <Response [200]>
# Processing batch 186/1095
# <Response [200]>
# Processing batch 187/1095
# <Response [200]>
# Processing batch 188/1095
# <Response [200]>
# Processing batch 189/1095
# <Response [200]>
# Processing batch 190/1095
# <Response [200]>
# Processing batch 191/1095
# <Response [200]>
# Processing batch 192/1095
# <Response [200]>
# Processing batch 193/1095
# <Response [200]>
# Processing batch 194/1095
# <Response [200]>
# Processing batch 195/1095
# <Response [200]>
# Processing batch 196/1095
# <Response [200]>
# Processing batch 197/1095
# <Response [200]>
# Processing batch 198/1095
# <Response [200]>
# Processing batch 199/1095
# <Response [200]>
# Processing batch 200/1095
# <Response [200]>
# Processing batch 201/1095
# <Response [200]>
# Processing batch 202/1095
# <Response [200]>
# Processing batch 203/1095
# <Response [200]>
# Processing batch 204/1095
# <Response [200]>
# Processing batch 205/1095
# <Response [200]>
# Processing batch 206/1095
# <Response [200]>
# Processing batch 207/1095
# <Response [200]>
# Processing batch 208/1095
# <Response [200]>
# Processing batch 209/1095
# <Response [200]>
# Processing batch 210/1095
# <Response [200]>
# Processing batch 211/1095
# <Response [200]>
# Processing batch 212/1095
# <Response [200]>
# Processing batch 213/1095
# <Response [200]>
# Processing batch 214/1095
# <Response [200]>
# Processing batch 215/1095
# <Response [200]>
# Processing batch 216/1095
# <Response [200]>
# Processing batch 217/1095
# <Response [200]>
# Processing batch 218/1095
# <Response [200]>
# Processing batch 219/1095
# <Response [200]>
# Processing batch 220/1095
# <Response [200]>
# Processing batch 221/1095
# <Response [200]>
# Processing batch 581/1095
# <Response [200]>
# Processing batch 582/1095
# <Response [200]>
# Processing batch 583/1095
# <Response [200]>
# Processing batch 584/1095
# <Response [200]>
# Processing batch 585/1095
# <Response [200]>
# Processing batch 586/1095
# <Response [200]>
# Processing batch 587/1095
# <Response [200]>
# Processing batch 588/1095
# <Response [200]>
# Processing batch 589/1095
# <Response [200]>
# Processing batch 590/1095
# <Response [200]>
# Processing batch 591/1095
# <Response [200]>
# Processing batch 592/1095
# <Response [200]>
# Processing batch 593/1095
# <Response [200]>
# Processing batch 594/1095
# <Response [200]>
# Processing batch 595/1095
# <Response [200]>
# Processing batch 596/1095
# <Response [200]>
# Processing batch 597/1095
# <Response [200]>
# Processing batch 598/1095
# <Response [200]>
# Processing batch 599/1095
# <Response [200]>
# Processing batch 600/1095
# <Response [200]>
# Processing batch 601/1095
# <Response [200]>
# Processing batch 602/1095
# <Response [200]>
# Processing batch 603/1095
# <Response [200]>
# Processing batch 604/1095
# <Response [200]>
# Processing batch 605/1095
# <Response [200]>
# Processing batch 606/1095
# <Response [200]>
# Processing batch 607/1095
# <Response [200]>
# Processing batch 608/1095
# <Response [200]>
# Processing batch 609/1095
# <Response [200]>
# Processing batch 610/1095
# <Response [200]>
# Processing batch 611/1095
# <Response [200]>
# Processing batch 612/1095
# <Response [200]>
# Processing batch 613/1095
# <Response [200]>
# Processing batch 614/1095
# <Response [200]>
# Processing batch 615/1095
# <Response [200]>
# Processing batch 616/1095
# <Response [200]>
# Processing batch 617/1095
# <Response [200]>
# Processing batch 618/1095
# <Response [200]>
# Processing batch 619/1095
# <Response [200]>
# Processing batch 620/1095
# <Response [200]>
# Processing batch 621/1095
# <Response [200]>
# Processing batch 622/1095
# <Response [200]>
# Processing batch 623/1095
# <Response [200]>
# Processing batch 624/1095
# <Response [200]>
# Processing batch 625/1095
# <Response [200]>
# Processing batch 626/1095
# <Response [200]>
# Processing batch 627/1095
# <Response [200]>
# Processing batch 628/1095
# <Response [200]>
# Processing batch 629/1095
# <Response [200]>
# Processing batch 630/1095
# <Response [200]>
# Processing batch 631/1095
# <Response [200]>
# Processing batch 632/1095
# <Response [200]>
# Processing batch 633/1095
# <Response [200]>
# Processing batch 634/1095
# <Response [200]>
# Processing batch 635/1095
# <Response [200]>
# Processing batch 636/1095
# <Response [200]>
# Processing batch 637/1095
# <Response [200]>
# Processing batch 638/1095
# <Response [200]>
# Processing batch 639/1095
# <Response [200]>
# Processing batch 640/1095
# <Response [200]>
# Processing batch 641/1095
# <Response [200]>
# Processing batch 642/1095
# <Response [200]>
# Processing batch 643/1095
# <Response [200]>
# Processing batch 644/1095
# <Response [200]>
# Processing batch 645/1095
# <Response [200]>
# Processing batch 646/1095
# <Response [200]>
# Processing batch 647/1095
# <Response [200]>
# Processing batch 648/1095
# <Response [200]>
# Processing batch 649/1095
# <Response [200]>
# Processing batch 650/1095
# <Response [200]>
# Processing batch 651/1095
# <Response [200]>
# Processing batch 652/1095
# <Response [200]>
# Processing batch 653/1095
# <Response [200]>
# Processing batch 654/1095
# <Response [200]>
# Processing batch 655/1095
# <Response [200]>
# Processing batch 656/1095
# <Response [200]>
# Processing batch 657/1095
# <Response [200]>
# Processing batch 658/1095
# <Response [200]>
# Processing batch 659/1095
# <Response [200]>
# Processing batch 660/1095
# <Response [200]>
# Processing batch 661/1095
# <Response [200]>
# Processing batch 662/1095
# <Response [200]>
# Processing batch 663/1095
# <Response [200]>
# Processing batch 664/1095
# <Response [200]>
# Processing batch 665/1095
# <Response [200]>
# Processing batch 666/1095
# <Response [200]>
# Processing batch 667/1095
# <Response [200]>
# Processing batch 668/1095
# <Response [200]>
# Processing batch 669/1095
# <Response [200]>
# Processing batch 670/1095
# <Response [200]>
# Processing batch 671/1095
# <Response [200]>
# Processing batch 672/1095
# <Response [200]>
# Processing batch 673/1095
# <Response [200]>
# Processing batch 674/1095
# <Response [200]>
# Processing batch 675/1095
# <Response [200]>
# Processing batch 676/1095
# <Response [200]>
# Processing batch 677/1095
# <Response [200]>
# Processing batch 678/1095
# <Response [200]>
# Processing batch 679/1095
# <Response [200]>
# Processing batch 680/1095
# <Response [200]>
# Processing batch 681/1095
# <Response [200]>
# Processing batch 682/1095
# <Response [200]>
# Processing batch 683/1095
# <Response [200]>
# Processing batch 684/1095
# <Response [200]>
# Processing batch 685/1095
# <Response [200]>
# Processing batch 686/1095
# <Response [200]>
# Processing batch 687/1095
# <Response [200]>
# Processing batch 688/1095
# <Response [200]>
# Processing batch 689/1095
# <Response [200]>
# Processing batch 690/1095
# <Response [200]>
# Processing batch 691/1095
# <Response [200]>
# Processing batch 692/1095
# <Response [200]>
# Processing batch 693/1095
# <Response [200]>
# Processing batch 694/1095
# <Response [200]>
# Processing batch 695/1095
# <Response [200]>
# Processing batch 696/1095
# <Response [200]>
# Processing batch 697/1095
# <Response [200]>
# Processing batch 698/1095
# <Response [200]>
# Processing batch 699/1095
# <Response [200]>
# Processing batch 700/1095
# <Response [200]>
# Processing batch 701/1095
# <Response [200]>
# Processing batch 702/1095
# <Response [200]>
# Processing batch 703/1095
# <Response [200]>
# Processing batch 704/1095
# <Response [200]>
# Processing batch 705/1095
# <Response [200]>
# Processing batch 706/1095
# <Response [200]>
# Processing batch 707/1095
# <Response [200]>
# Processing batch 708/1095
# <Response [200]>
# Processing batch 709/1095
# <Response [200]>
# Processing batch 710/1095
# <Response [200]>
# Processing batch 711/1095
# <Response [200]>
# Processing batch 712/1095
# <Response [200]>
# Processing batch 713/1095
# <Response [200]>
# Processing batch 714/1095
# <Response [200]>
# Processing batch 715/1095
# <Response [200]>
# Processing batch 716/1095
# <Response [200]>
# Processing batch 717/1095
# <Response [200]>
# Processing batch 718/1095
# <Response [200]>
# Processing batch 719/1095
# <Response [200]>
# Processing batch 720/1095
# <Response [200]>
# Processing batch 721/1095
# <Response [200]>
# Processing batch 722/1095
# <Response [200]>
# Processing batch 723/1095
# <Response [200]>
# Processing batch 724/1095
# <Response [200]>
# Processing batch 725/1095
# <Response [200]>
# Processing batch 726/1095
# <Response [200]>
# Processing batch 727/1095
# <Response [200]>
# Processing batch 728/1095
# <Response [200]>
# Processing batch 729/1095
# <Response [200]>
# Processing batch 730/1095
# <Response [200]>
# Processing batch 731/1095
# <Response [200]>
# Processing batch 732/1095
# <Response [200]>
# Processing batch 733/1095
# <Response [200]>
# Processing batch 734/1095
# <Response [200]>
# Processing batch 735/1095
# <Response [200]>
# Processing batch 736/1095
# <Response [200]>
# Processing batch 737/1095
# <Response [200]>
# Processing batch 738/1095
# <Response [200]>
# Processing batch 739/1095
# <Response [200]>
# Processing batch 740/1095
# <Response [200]>
# Processing batch 741/1095
# <Response [200]>
# Processing batch 742/1095
# <Response [200]>
# Processing batch 743/1095
# <Response [200]>
# Processing batch 744/1095
# <Response [200]>
# Processing batch 745/1095
# <Response [200]>
# Processing batch 746/1095
# <Response [200]>
# Processing batch 747/1095
# <Response [200]>
# Processing batch 748/1095
# <Response [200]>
# Processing batch 749/1095
# <Response [200]>
# Processing batch 750/1095
# <Response [200]>
# Processing batch 751/1095
# <Response [200]>
# Processing batch 752/1095
# <Response [200]>
# Processing batch 753/1095
# <Response [200]>
# Processing batch 754/1095
# <Response [200]>
# Processing batch 755/1095
# <Response [200]>
# Processing batch 756/1095
# <Response [200]>
# Processing batch 757/1095
# <Response [200]>
# Processing batch 758/1095
# <Response [200]>
# Processing batch 759/1095
# <Response [200]>
# Processing batch 760/1095
# <Response [200]>
# Processing batch 761/1095
# <Response [200]>
# Processing batch 762/1095
# <Response [200]>
# Processing batch 763/1095
# <Response [200]>
# Processing batch 764/1095
# <Response [200]>
# Processing batch 765/1095
# <Response [200]>
# Processing batch 766/1095
# <Response [200]>
# Processing batch 767/1095
# <Response [200]>
# Processing batch 768/1095
# <Response [200]>
# Processing batch 769/1095
# <Response [200]>
# Processing batch 770/1095
# <Response [200]>
# Processing batch 771/1095
# <Response [200]>
# Processing batch 772/1095
# <Response [200]>
# Processing batch 773/1095
# <Response [200]>
# Processing batch 774/1095
# <Response [200]>
# Processing batch 775/1095
# <Response [200]>
# Processing batch 776/1095
# <Response [200]>
# Processing batch 777/1095
# <Response [200]>
# Processing batch 778/1095
# <Response [200]>
# Processing batch 779/1095
# <Response [200]>
# Processing batch 780/1095
# <Response [200]>
# Processing batch 781/1095
# <Response [200]>
# Processing batch 782/1095
# <Response [200]>
# Processing batch 783/1095
# <Response [200]>
# Processing batch 784/1095
# <Response [200]>
# Processing batch 785/1095
# <Response [200]>
# Processing batch 786/1095
# <Response [200]>
# Processing batch 787/1095
# <Response [200]>
# Processing batch 788/1095
# <Response [200]>
# Processing batch 789/1095
# <Response [200]>
# Processing batch 790/1095
# <Response [200]>
# Processing batch 791/1095
# <Response [200]>
# Processing batch 792/1095
# <Response [200]>
# Processing batch 793/1095
# <Response [200]>
# Processing batch 794/1095
# <Response [200]>
# Processing batch 795/1095
# <Response [200]>
# Processing batch 796/1095
# <Response [200]>
# Processing batch 797/1095
# <Response [200]>
# Processing batch 798/1095
# <Response [200]>
# Processing batch 799/1095
# <Response [200]>
# Processing batch 800/1095
# <Response [200]>
# Processing batch 801/1095
# <Response [200]>
# Processing batch 802/1095
# <Response [200]>
# Processing batch 803/1095
# <Response [200]>
# Processing batch 804/1095
# <Response [200]>
# Processing batch 805/1095
# <Response [200]>
# Processing batch 806/1095
# <Response [200]>
# Processing batch 807/1095
# <Response [200]>
# Processing batch 808/1095
# <Response [200]>
# Processing batch 809/1095
# <Response [200]>
# Processing batch 810/1095
# <Response [200]>
# Processing batch 811/1095
# <Response [200]>
# Processing batch 812/1095
# <Response [200]>
# Processing batch 813/1095
# <Response [200]>
# Processing batch 814/1095
# <Response [200]>
# Processing batch 815/1095
# <Response [200]>
# Processing batch 816/1095
# <Response [200]>
# Processing batch 817/1095
# <Response [200]>
# Processing batch 818/1095
# <Response [200]>
# Processing batch 819/1095
# <Response [200]>
# Processing batch 820/1095
# <Response [200]>
# Processing batch 821/1095
# <Response [200]>
# Processing batch 822/1095
# <Response [200]>
# Processing batch 823/1095
# <Response [200]>
# Processing batch 824/1095
# <Response [200]>
# Processing batch 825/1095
# <Response [200]>
# Processing batch 826/1095
# <Response [200]>
# Processing batch 827/1095
# <Response [200]>
# Processing batch 828/1095
# <Response [200]>
# Processing batch 829/1095
# <Response [200]>
# Processing batch 830/1095
# <Response [200]>
# Processing batch 831/1095
# <Response [200]>
# Processing batch 832/1095
# <Response [200]>
# Processing batch 833/1095
# <Response [200]>
# Processing batch 834/1095
# <Response [200]>
# Processing batch 835/1095
# <Response [200]>
# Processing batch 836/1095
# <Response [200]>
# Processing batch 837/1095
# <Response [200]>
# Processing batch 838/1095
# <Response [200]>
# Processing batch 839/1095
# <Response [200]>
# Processing batch 840/1095
# <Response [200]>
# Processing batch 841/1095
# <Response [200]>
# Processing batch 842/1095
# <Response [200]>
# Processing batch 843/1095
# <Response [200]>
# Processing batch 844/1095
# <Response [200]>
# Processing batch 845/1095
# <Response [200]>
# Processing batch 846/1095
# <Response [200]>
# Processing batch 847/1095
# <Response [200]>
# Processing batch 848/1095
# <Response [200]>
# Processing batch 849/1095
# <Response [200]>
# Processing batch 850/1095
# <Response [200]>
# Processing batch 851/1095
# <Response [200]>
# Processing batch 852/1095
# <Response [200]>
# Processing batch 853/1095
# <Response [200]>
# Processing batch 854/1095
# <Response [200]>
# Processing batch 855/1095
# <Response [200]>
# Processing batch 856/1095
# <Response [200]>
# Processing batch 857/1095
# <Response [200]>
# Processing batch 858/1095
# <Response [200]>
# Processing batch 859/1095
# <Response [200]>
# Processing batch 860/1095
# <Response [200]>
# Processing batch 861/1095
# <Response [200]>
# Processing batch 862/1095
# <Response [200]>
# Processing batch 863/1095
# <Response [200]>
# Processing batch 864/1095
# <Response [200]>
# Processing batch 865/1095
# <Response [200]>
# Processing batch 866/1095
# <Response [200]>
# Processing batch 867/1095
# <Response [200]>
# Processing batch 868/1095
# <Response [200]>
# Processing batch 869/1095
# <Response [200]>
# Processing batch 870/1095
# <Response [200]>
# Processing batch 871/1095
# <Response [200]>
# Processing batch 872/1095
# <Response [200]>
# Processing batch 873/1095
# <Response [200]>
# Processing batch 874/1095
# <Response [200]>
# Processing batch 875/1095
# <Response [200]>
# Processing batch 876/1095
# <Response [200]>
# Processing batch 877/1095
# <Response [200]>
# Processing batch 878/1095
# <Response [200]>
# Processing batch 879/1095
# <Response [200]>
# Processing batch 880/1095
# <Response [200]>
# Processing batch 881/1095
# <Response [200]>
# Processing batch 882/1095
# <Response [200]>
# Processing batch 883/1095
# <Response [200]>
# Processing batch 884/1095
# <Response [200]>
# Processing batch 885/1095
# <Response [200]>
# Processing batch 886/1095
# <Response [200]>
# Processing batch 887/1095
# <Response [200]>
# Processing batch 888/1095
# <Response [200]>
# Processing batch 889/1095
# <Response [200]>
# Processing batch 890/1095
# <Response [200]>
# Processing batch 891/1095
# <Response [200]>
# Processing batch 892/1095
# <Response [200]>
# Processing batch 893/1095
# <Response [200]>
# Processing batch 894/1095
# <Response [200]>
# Processing batch 895/1095
# <Response [200]>
# Processing batch 896/1095
# <Response [200]>
# Processing batch 897/1095
# <Response [200]>
# Processing batch 898/1095
# <Response [200]>
# Processing batch 899/1095
# <Response [200]>
# Processing batch 900/1095
# <Response [200]>
# Processing batch 901/1095
# <Response [200]>
# Processing batch 902/1095
# <Response [200]>
# Processing batch 903/1095
# <Response [200]>
# Processing batch 904/1095
# <Response [200]>
# Processing batch 905/1095
# <Response [200]>
# Processing batch 906/1095
# <Response [200]>
# Processing batch 907/1095
# <Response [200]>
# Processing batch 908/1095
# <Response [200]>
# Processing batch 909/1095
# <Response [200]>
# Processing batch 910/1095
# <Response [200]>
# Processing batch 911/1095
# <Response [200]>
# Processing batch 912/1095
# <Response [200]>
# Processing batch 913/1095
# <Response [200]>
# Processing batch 914/1095
# <Response [200]>
# Processing batch 915/1095
# <Response [200]>
# Processing batch 916/1095
# <Response [200]>
# Processing batch 917/1095
# <Response [200]>
# Processing batch 918/1095
# <Response [200]>
# Processing batch 919/1095
# <Response [200]>
# Processing batch 920/1095
# <Response [200]>
# Processing batch 921/1095
# <Response [200]>
# Processing batch 922/1095
# <Response [200]>
# Processing batch 923/1095
# <Response [200]>
# Processing batch 924/1095
# <Response [200]>
# Processing batch 925/1095
# <Response [200]>
# Processing batch 926/1095
# <Response [200]>
# Processing batch 927/1095
# <Response [200]>
# Processing batch 928/1095
# <Response [200]>
# Processing batch 929/1095
# <Response [200]>
# Processing batch 930/1095
# <Response [200]>
# Processing batch 931/1095
# <Response [200]>
# Processing batch 932/1095
# <Response [200]>
# Processing batch 933/1095
# <Response [200]>
# Processing batch 934/1095
# <Response [200]>
# Processing batch 935/1095
# <Response [200]>
# Processing batch 936/1095
# <Response [200]>
# Processing batch 937/1095
# <Response [200]>
# Processing batch 938/1095
# <Response [200]>
# Processing batch 939/1095
# <Response [200]>
# Processing batch 940/1095
# <Response [200]>
# Processing batch 941/1095
# <Response [200]>
# Processing batch 942/1095
# <Response [200]>
# Processing batch 943/1095
# <Response [200]>
# Processing batch 944/1095
# <Response [200]>
# Processing batch 945/1095
# <Response [200]>
# Processing batch 946/1095
# <Response [200]>
# Processing batch 947/1095
# <Response [200]>
# Processing batch 948/1095
# <Response [200]>
# Processing batch 949/1095
# <Response [200]>
# Processing batch 950/1095
# <Response [200]>
# Processing batch 951/1095
# <Response [200]>
# Processing batch 952/1095
# <Response [200]>
# Processing batch 953/1095
# <Response [200]>
# Processing batch 954/1095
# <Response [200]>
# Processing batch 955/1095
# <Response [200]>
# Processing batch 956/1095
# <Response [200]>
# Processing batch 957/1095
# <Response [200]>
# Processing batch 958/1095
# <Response [200]>
# Processing batch 959/1095
# <Response [200]>
# Processing batch 960/1095
# <Response [200]>
# Processing batch 961/1095
# <Response [200]>
# Processing batch 962/1095
# <Response [200]>
# Processing batch 963/1095
# <Response [200]>
# Processing batch 964/1095
# <Response [200]>
# Processing batch 965/1095
# <Response [200]>
# Processing batch 966/1095
# <Response [200]>
# Processing batch 967/1095
# <Response [200]>
# Processing batch 968/1095
# <Response [200]>
# Processing batch 969/1095
# <Response [200]>
# Processing batch 970/1095
# <Response [200]>
# Processing batch 971/1095
# <Response [200]>
# Processing batch 972/1095
# <Response [200]>
# Processing batch 973/1095
# <Response [200]>
# Processing batch 974/1095
# <Response [200]>
# Processing batch 975/1095
# <Response [200]>
# Processing batch 976/1095
# <Response [200]>
# Processing batch 977/1095
# <Response [200]>
# Processing batch 978/1095
# <Response [200]>
# Processing batch 979/1095
# <Response [200]>
# Processing batch 980/1095
# <Response [200]>
# Processing batch 981/1095
# <Response [200]>
# Processing batch 982/1095
# <Response [200]>
# Processing batch 983/1095
# <Response [200]>
# Processing batch 984/1095
# <Response [200]>
# Processing batch 985/1095
# <Response [200]>
# Processing batch 986/1095
# <Response [200]>
# Processing batch 987/1095
# <Response [200]>
# Processing batch 988/1095
# <Response [200]>
# Processing batch 989/1095
# <Response [200]>
# Processing batch 990/1095
# <Response [200]>
# Processing batch 991/1095
# <Response [200]>
# Processing batch 992/1095
# <Response [200]>
# Processing batch 993/1095
# <Response [200]>
# Processing batch 994/1095
# <Response [200]>
# Processing batch 995/1095
# <Response [200]>
# Processing batch 996/1095
# <Response [200]>
# Processing batch 997/1095
# <Response [200]>
# Processing batch 998/1095
# <Response [200]>
# Processing batch 999/1095
# <Response [200]>
# Processing batch 1000/1095
# <Response [200]>
# Processing batch 1001/1095
# <Response [200]>
# Processing batch 1002/1095
# <Response [200]>
# Processing batch 1003/1095
# <Response [200]>
# Processing batch 1004/1095
# <Response [200]>
# Processing batch 1005/1095
# <Response [200]>
# Processing batch 1006/1095
# <Response [200]>
# Processing batch 1007/1095
# <Response [200]>
# Processing batch 1008/1095
# <Response [200]>
# Processing batch 1009/1095
# <Response [200]>
# Processing batch 1010/1095
# <Response [200]>
# Processing batch 1011/1095
# <Response [200]>
# Processing batch 1012/1095
# <Response [200]>
# Processing batch 1013/1095
# <Response [200]>
# Processing batch 1014/1095
# <Response [200]>
# Processing batch 1015/1095
# <Response [200]>
# Processing batch 1016/1095
# <Response [200]>
# Processing batch 1017/1095
# <Response [200]>
# Processing batch 1018/1095
# <Response [200]>
# Processing batch 1019/1095
# <Response [200]>
# Processing batch 1020/1095
# <Response [200]>
# Processing batch 1021/1095
# <Response [200]>
# Processing batch 1022/1095
# <Response [200]>
# Processing batch 1023/1095
# <Response [200]>
# Processing batch 1024/1095
# <Response [200]>
# Processing batch 1025/1095
# <Response [200]>
# Processing batch 1026/1095
# <Response [200]>
# Processing batch 1027/1095
# <Response [200]>
# Processing batch 1028/1095
# <Response [200]>
# Processing batch 1029/1095
# <Response [200]>
# Processing batch 1030/1095
# <Response [200]>
# Processing batch 1031/1095
# <Response [200]>
# Processing batch 1032/1095
# <Response [200]>
# Processing batch 1033/1095
# <Response [200]>
# Processing batch 1034/1095
# <Response [200]>
# Processing batch 1035/1095
# <Response [200]>
# Processing batch 1036/1095
# <Response [200]>
# Processing batch 1037/1095
# <Response [200]>
# Processing batch 1038/1095
# <Response [200]>
# Processing batch 1039/1095
# <Response [200]>
# Processing batch 1040/1095
# <Response [200]>
# Processing batch 1041/1095
# <Response [200]>
# Processing batch 1042/1095
# <Response [200]>
# Processing batch 1043/1095
# <Response [200]>
# Processing batch 1044/1095
# <Response [200]>
# Processing batch 1045/1095
# <Response [200]>
# Processing batch 1046/1095
# <Response [200]>
# Processing batch 1047/1095
# <Response [200]>
# Processing batch 1048/1095
# <Response [200]>
# Processing batch 1049/1095
# <Response [200]>
# Processing batch 1050/1095
# <Response [200]>
# Processing batch 1051/1095
# <Response [200]>
# Processing batch 1052/1095
# <Response [200]>
# Processing batch 1053/1095
# <Response [200]>
# Processing batch 1054/1095
# <Response [200]>
# Processing batch 1055/1095
# <Response [200]>
# Processing batch 1056/1095
# <Response [200]>
# Processing batch 1057/1095
# <Response [200]>
# Processing batch 1058/1095
# <Response [200]>
# Processing batch 1059/1095
# <Response [200]>
# Processing batch 1060/1095
# <Response [200]>
# Processing batch 1061/1095
# <Response [200]>
# Processing batch 1062/1095
# <Response [200]>
# Processing batch 1063/1095
# <Response [200]>
# Processing batch 1064/1095
# <Response [200]>
# Processing batch 1065/1095
# <Response [200]>
# Processing batch 1066/1095
# <Response [200]>
# Processing batch 1067/1095
# <Response [200]>
# Processing batch 1068/1095
# <Response [200]>
# Processing batch 1069/1095
# <Response [200]>
# Processing batch 1070/1095
# <Response [200]>
# Processing batch 1071/1095
# <Response [200]>
# Processing batch 1072/1095
# <Response [200]>
# Processing batch 1073/1095
# <Response [200]>
# Processing batch 1074/1095
# <Response [200]>
# Processing batch 1075/1095
# <Response [200]>
# Processing batch 1076/1095
# <Response [200]>
# Processing batch 1077/1095
# <Response [200]>
# Processing batch 1078/1095
# <Response [200]>
# Processing batch 1079/1095
# <Response [200]>
# Processing batch 1080/1095
# <Response [200]>
# Processing batch 1081/1095
# <Response [200]>
# Processing batch 1082/1095
# <Response [200]>
# Processing batch 1083/1095
# <Response [200]>
# Processing batch 1084/1095
# <Response [200]>
# Processing batch 1085/1095
# <Response [200]>
# Processing batch 1086/1095
# <Response [200]>
# Processing batch 1087/1095
# <Response [200]>
# Processing batch 1088/1095
# <Response [200]>
# Processing batch 1089/1095
# <Response [200]>
# Processing batch 1090/1095
# <Response [200]>
# Processing batch 1091/1095
# <Response [200]>
# Processing batch 1092/1095
# <Response [200]>
# Processing batch 1093/1095
# <Response [200]>
# Processing batch 1094/1095
# <Response [200]>
# Processing batch 1095/1095
# <Response [200]>
# Data retrieval completed

# %% [markdown]
# ## Ignoring the API
# Create the song_metadata.json file without the API.
#
# Don't need this part if API does not rate limit you

# %%
# Create an empty list to store the song metadata
song_metadata = []

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    # Create a dictionary with the song metadata
    song_info = {
        'id': index,
        'name': row['track_name'],
        'track_id': row['track_id'],
        'artists': [row['track_artist']],
        'image_url': "",
        'track_url': "",
        'preview_url': ""
    }
    song_metadata.append(song_info)

# Save the song metadata to a JSON file
with open('temp_data/song_metadata.json', 'w') as file:
    json.dump(song_metadata, file, indent=4)

print("Song metadata saved to 'song_metadata.json'")
# Out:
# Song metadata saved to 'song_metadata.json'

# %% [markdown]
# ### Save track IDs in a csv
#
# Save 50 track IDs as a line in csv

# %%
# Specify the path to the song metadata JSON file
json_file_path = 'temp_data/song_metadata.json'

# Specify the path to the output CSV file
csv_file_path = 'track_id_batches.csv'

# Specify the batch size (number of track IDs per batch)
batch_size = 50

# Read the song metadata from the JSON file
with open(json_file_path, 'r') as file:
    song_metadata = json.load(file)

# Extract the track IDs from the song metadata
track_ids = [song['track_id'] for song in song_metadata]

# Create batches of track IDs
track_id_batches = [track_ids[i:i+batch_size] for i in range(0, len(track_ids), batch_size)]

# Save the track ID batches to a CSV file
with open(csv_file_path, 'w', newline='') as file:
    writer = csv.writer(file)
    for batch in track_id_batches:
        writer.writerow([','.join(batch)])

print(f"Track ID batches saved to '{csv_file_path}'")
# Out:
# Track ID batches saved to 'track_id_batches.csv'

# %% [markdown]
# ### Parse output from spotify api

# %%
# Specify the path to the song metadata JSON file
json_file_path = 'temp_data/spotify_res.json'

song_metadata = []

# Read the song metadata from the JSON file
with open(json_file_path, 'r') as file:
    track_data = json.load(file)

for track in track_data["tracks"]:
    track_id = track['id']
    track_name = track['name']
    track_url = track['external_urls']['spotify']
    preview_url = track['preview_url']
    image_url = track['album']['images'][0]['url'] if track['album']['images'] else ""
    artists = [artist["name"] for artist in track["album"]["artists"]]
    
    # Find the corresponding index in the DataFrame
    index = df.index[df['track_id'] == track_id].tolist()[0]
    
    # Create a dictionary with the song metadata
    song_info = {
        'id': index,
        'name': df.loc[index, 'track_name'],
        'track_id': track_id,
        'artists': artists,
        'image_url': image_url,
        'track_url': track_url,
        'preview_url': preview_url
    }
    song_metadata.append(song_info)

# Save the song metadata to a JSON file
with open('temp_data/spotify_res_cleaned.json', 'w') as file:
    json.dump(song_metadata, file, indent=4)

print("Song metadata saved to 'spotify_res_cleaned.json'")
# Out:
# Song metadata saved to 'spotify_res_cleaned.json'

# %% [markdown]
# ### Use cleaned output to update song_metadata.json

# %%
# Specify the path to the song metadata JSON file
cleaned_json_path = 'temp_data/spotify_res_cleaned.json'

song_metadata_path = 'temp_data/song_metadata.json'

# Read the batched cleaned metadata
with open(cleaned_json_path, 'r') as file:
    cleaned_data = json.load(file)

# open the song metadata json file
with open(song_metadata_path, 'r') as file:
    song_metadata = json.load(file)

for cleaned_track in cleaned_data:
    id = cleaned_track["id"]
    metadata = song_metadata[id]
    metadata["artists"] = cleaned_track["artists"]
    metadata["image_url"] = cleaned_track["image_url"]
    metadata["track_url"] = cleaned_track["track_url"]
    metadata["preview_url"] = cleaned_track["preview_url"]

# Save the updated song metadata to a JSON file
with open('temp_data/song_metadata.json', 'w') as file:
    json.dump(song_metadata, file, indent=4)

print("Updated song metadata saved to 'spotify_res_cleaned.json'")
# Out:
# Updated song metadata saved to 'spotify_res_cleaned.json'

# %% [markdown]
# ## Validate Metadata

# %%
# Specify the path to the song metadata JSON file
json_file_path = 'song_metadata.json'

# Read the song metadata from the JSON file
with open(json_file_path, 'r') as file:
    song_metadata = json.load(file)

# Get the unique track IDs and names from the DataFrame
df_track_ids = set(df['track_id'])
df_names = dict(zip(df['track_id'], df['track_name']))

# Check if all the track IDs from the DataFrame exist in the JSON objects
json_track_ids = set(song['track_id'] for song in song_metadata)
missing_track_ids = df_track_ids - json_track_ids

if missing_track_ids:
    print(f"Missing track IDs: {missing_track_ids}")
    print("Please ensure all track IDs from the DataFrame exist in the JSON objects.")
else:
    print("All track IDs from the DataFrame exist in the JSON objects.\n")

    # Validate if the names in the JSON objects match the corresponding names in the DataFrame
    mismatched_names = []
    for song in song_metadata:
        if song['track_id'] in df_names and song['name'] != df_names[song['track_id']]:
            mismatched_names.append(song['track_id'])

    if mismatched_names:
        print(f"Mismatched names for track IDs: {mismatched_names}")
        print("Please ensure the names in the JSON objects match the corresponding names in the DataFrame.")
    else:
        print("All names in the JSON objects match the corresponding names in the DataFrame.")

        # Sort the song metadata based on the "id" field in ascending order
        sorted_song_metadata = sorted(song_metadata, key=lambda x: x['id'])

        # Save the sorted song metadata back to the JSON file
        with open(json_file_path, 'w') as file:
            json.dump(sorted_song_metadata, file, indent=4)

        print(f"Song metadata sorted and saved to '{json_file_path}'")
# Out:
# All track IDs from the DataFrame exist in the JSON objects.
#
# Mismatched names for track IDs: ['69gRFGOWY9OMpFJgFol1u0', '5cjecvX0CmC9gK0Laf5EMQ', '5TTzhRSWQS4Yu8xTgAuq6D', '3VKFip3OdAvv4OfNTgFWeQ', '69gRFGOWY9OMpFJgFol1u0']
# Please ensure the names in the JSON objects match the corresponding names in the DataFrame.
